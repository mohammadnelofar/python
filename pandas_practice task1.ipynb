# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r"C:\\Users\nehasulthana\Downloads\inventory.csv")
df
# Out:
#          location  product_type         product_description  quantity  price
# 0   Staten Island         seeds                       daisy         4   6.99
# 1   Staten Island         seeds                  calla lily        46  19.99
# 2   Staten Island         seeds                      tomato        85  13.99
# 3   Staten Island  garden tools                        rake         4  13.99
# 4   Staten Island  garden tools                 wheelbarrow         0  89.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 7   Staten Island  pest_control                 weed killer         8  23.99
# 8   Staten Island       planter  20 inch terracotta planter         0  17.99
# 9   Staten Island       planter      8 inch plastic planter        53   3.99
# 10       Brooklyn         seeds                       daisy        50   6.99
# ...

# %%
df.head(10)
# Out:
#         location  product_type         product_description  quantity  price
# 0  Staten Island         seeds                       daisy         4   6.99
# 1  Staten Island         seeds                  calla lily        46  19.99
# 2  Staten Island         seeds                      tomato        85  13.99
# 3  Staten Island  garden tools                        rake         4  13.99
# 4  Staten Island  garden tools                 wheelbarrow         0  89.99
# 5  Staten Island  garden tools                       spade        93  19.99
# 6  Staten Island  pest_control               insect killer        74  12.99
# 7  Staten Island  pest_control                 weed killer         8  23.99
# 8  Staten Island       planter  20 inch terracotta planter         0  17.99
# 9  Staten Island       planter      8 inch plastic planter        53   3.99

# %%
df.tail()
# Out:
#    location  product_type         product_description  quantity  price  \
# 24   Queens  garden tools                 wheelbarrow      True  89.99
# 25   Queens  garden tools                       spade      True  19.99
# 26   Queens  pest_control               insect killer     False  12.99
# 27   Queens  pest_control                 weed killer      True  23.99
# 28   Queens       planter  20 inch terracotta planter      True  17.99
#
#     in_stock  total_value                        full_description
# 24      True        89.99            garden tools and wheelbarrow
# 25      True        19.99                  garden tools and spade
# 26      True         0.00          pest_control and insect killer
# 27      True        23.99            pest_control and weed killer
# 28      True        17.99  planter and 20 inch terracotta planter

# %%
df.describe()
# Out:
#         quantity      price
# count  29.000000  29.000000
# mean   40.758621  23.024483
# std    35.183859  23.810986
# min     0.000000   3.990000
# 25%     5.000000  12.990000
# 50%    36.000000  17.990000
# 75%    76.000000  19.990000
# max    98.000000  89.990000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   location             29 non-null     object
#  1   product_type         29 non-null     object
#  2   product_description  29 non-null     object
#  3   quantity             29 non-null     int64
#  4   price                29 non-null     float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 1.3+ KB

# %% [markdown]
# ### what products are sold at your Staten Island location?

# %%
df[df['location']=='Staten Island'].product_description
# Out:
# 0                         daisy
# 1                    calla lily
# 2                        tomato
# 3                          rake
# 4                   wheelbarrow
# 5                         spade
# 6                 insect killer
# 7                   weed killer
# 8    20 inch terracotta planter
# 9        8 inch plastic planter
# Name: product_description, dtype: object

# %% [markdown]
# ### what types of seeds are sold at the Brooklyn location.

# %%
df[df['location']=='Brooklyn'].product_description.unique()
# Out:
# array(['daisy', 'calla lily', 'tomato', 'rake', 'wheelbarrow', 'spade',
#        'insect killer', 'weed killer', '20 inch terracotta planter',
#        '8 inch plastic planter'], dtype=object)

# %% [markdown]
# ### Add a column called in_stock which is True if quantity is greater than 0 and False if quantity equals 0.

# %%
df['quantity']=df.quantity.apply(lambda row:True if row >0 else False)
df
# Out:
#          location  product_type         product_description  quantity  price  \
# 0   Staten Island         seeds                       daisy      True   6.99
# 1   Staten Island         seeds                  calla lily      True  19.99
# 2   Staten Island         seeds                      tomato      True  13.99
# 3   Staten Island  garden tools                        rake      True  13.99
# 4   Staten Island  garden tools                 wheelbarrow     False  89.99
# 5   Staten Island  garden tools                       spade      True  19.99
# 6   Staten Island  pest_control               insect killer      True  12.99
# 7   Staten Island  pest_control                 weed killer      True  23.99
# 8   Staten Island       planter  20 inch terracotta planter     False  17.99
# 9   Staten Island       planter      8 inch plastic planter      True   3.99
# 10       Brooklyn         seeds                       daisy      True   6.99
# ...

# %%
# Create a column called  total_value that is equal to price multiplied by quantity.
df['total_value']=df.apply(lambda row:row['price']* row['quantity'],axis=1)
df
# Out:
#          location  product_type         product_description  quantity  price  \
# 0   Staten Island         seeds                       daisy      True   6.99
# 1   Staten Island         seeds                  calla lily      True  19.99
# 2   Staten Island         seeds                      tomato      True  13.99
# 3   Staten Island  garden tools                        rake      True  13.99
# 4   Staten Island  garden tools                 wheelbarrow     False  89.99
# 5   Staten Island  garden tools                       spade      True  19.99
# 6   Staten Island  pest_control               insect killer      True  12.99
# 7   Staten Island  pest_control                 weed killer      True  23.99
# 8   Staten Island       planter  20 inch terracotta planter     False  17.99
# 9   Staten Island       planter      8 inch plastic planter      True   3.99
# 10       Brooklyn         seeds                       daisy      True   6.99
# ...

# %% [markdown]
# ### create a new column called  full_description that has the complete description of each product. ( product type and product description)

# %%
df['full_description']=df.apply(lambda row:row['product_type']+' and '+row['product_description'] ,axis=1)
df
# Out:
#          location  product_type         product_description  quantity  price  \
# 0   Staten Island         seeds                       daisy      True   6.99
# 1   Staten Island         seeds                  calla lily      True  19.99
# 2   Staten Island         seeds                      tomato      True  13.99
# 3   Staten Island  garden tools                        rake      True  13.99
# 4   Staten Island  garden tools                 wheelbarrow     False  89.99
# 5   Staten Island  garden tools                       spade      True  19.99
# 6   Staten Island  pest_control               insect killer      True  12.99
# 7   Staten Island  pest_control                 weed killer      True  23.99
# 8   Staten Island       planter  20 inch terracotta planter     False  17.99
# 9   Staten Island       planter      8 inch plastic planter      True   3.99
# 10       Brooklyn         seeds                       daisy      True   6.99
# ...
